# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
file = "Data/PopulationPerStateandCounty.csv"
population = pd.read_csv(file)

# %%
#population = population.drop(population.index[0])

# %%
new_df=population[["State","Area_Name","CENSUS_2010_POP", "POP_ESTIMATE_2011", 
                   "POP_ESTIMATE_2012", "POP_ESTIMATE_2013", "POP_ESTIMATE_2014",
                   "POP_ESTIMATE_2015", "POP_ESTIMATE_2016", "POP_ESTIMATE_2017","POP_ESTIMATE_2018", 
                   "Births_2010", "Births_2011", "Births_2012", "Births_2013", "Births_2014", "Births_2015",
                   "Births_2016", "Births_2017", "Births_2018"
                    ]]
new_df
# Out:
#      State                         Area_Name CENSUS_2010_POP  \
# 0       US                     United States     308,745,538
# 1       AL                           Alabama       4,779,736
# 2       AL                    Autauga County          54,571
# 3       AL                    Baldwin County         182,265
# 4       AL                    Barbour County          27,457
# ...    ...                               ...             ...
# 3268    PR  Vega Baja Municipio, Puerto Rico          59,662
# 3269    PR    Vieques Municipio, Puerto Rico           9,301
# 3270    PR   Villalba Municipio, Puerto Rico          26,073
# 3271    PR    Yabucoa Municipio, Puerto Rico          37,941
# 3272    PR      Yauco Municipio, Puerto Rico          42,043
#
#      POP_ESTIMATE_2011 POP_ESTIMATE_2012 POP_ESTIMATE_2013 POP_ESTIMATE_2014  \
# 0          311,580,009       313,874,218       316,057,727       318,386,421
# ...

# %%
#no Puerto Rico
new_df=new_df.loc[new_df["State"]!="PR",:]
new_df
# Out:
#      State          Area_Name CENSUS_2010_POP POP_ESTIMATE_2011  \
# 0       US      United States     308,745,538       311,580,009
# 1       AL            Alabama       4,779,736         4,798,834
# 2       AL     Autauga County          54,571            55,208
# 3       AL     Baldwin County         182,265           186,540
# 4       AL     Barbour County          27,457            27,350
# ...    ...                ...             ...               ...
# 3189    WY  Sweetwater County          43,806            43,981
# 3190    WY       Teton County          21,294            21,414
# 3191    WY       Uinta County          21,118            20,893
# 3192    WY    Washakie County           8,533             8,448
# 3193    WY      Weston County           7,208             7,142
#
#      POP_ESTIMATE_2012 POP_ESTIMATE_2013 POP_ESTIMATE_2014 POP_ESTIMATE_2015  \
# 0          313,874,218       316,057,727       318,386,421       320,742,673
# ...

# %%
new_df=new_df.rename(columns={"Area_Name":"Area Name", "CENSUS_2010_POP":"2010 Population", "POP_ESTIMATE_2011":"2011 Population",
                             "POP_ESTIMATE_2012":"2012 Population", "POP_ESTIMATE_2013":"2013 Population", "POP_ESTIMATE_2014":"2014 Population",
                             "POP_ESTIMATE_2015":"2015 Population", "POP_ESTIMATE_2016":"2016 Population", "POP_ESTIMATE_2017":"2017 Population",
                             "POP_ESTIMATE_2018":"2018 Population", "Births_2010":"2010 Birth", "Births_2011":"2011 Birth", "Births_2012":"2012 Birth",
                              "Births_2013":"2013 Birth","Births_2014":"2014 Birth", "Births_2015":"2015 Birth", "Births_2016":"2016 Birth", 
                              "Births_2017":"2017 Birth", "Births_2018":"2018 Birth"
                             } )
new_df
# Out:
#      State          Area Name 2010 Population 2011 Population 2012 Population  \
# 0       US      United States     308,745,538     311,580,009     313,874,218
# 1       AL            Alabama       4,779,736       4,798,834       4,815,564
# 2       AL     Autauga County          54,571          55,208          54,936
# 3       AL     Baldwin County         182,265         186,540         190,143
# 4       AL     Barbour County          27,457          27,350          27,174
# ...    ...                ...             ...             ...             ...
# 3189    WY  Sweetwater County          43,806          43,981          45,005
# 3190    WY       Teton County          21,294          21,414          21,625
# 3191    WY       Uinta County          21,118          20,893          20,994
# 3192    WY    Washakie County           8,533           8,448           8,408
# 3193    WY      Weston County           7,208           7,142           7,077
#
# ...

# %%
new_df.count()
# Out:
# State              3194
# Area Name          3194
# 2010 Population    3194
# 2011 Population    3194
# 2012 Population    3194
# 2013 Population    3194
# 2014 Population    3194
# 2015 Population    3194
# 2016 Population    3194
# 2017 Population    3194
# 2018 Population    3194
# 2010 Birth         3194
# 2011 Birth         3194
# 2012 Birth         3194
# 2013 Birth         3194
# 2014 Birth         3194
# 2015 Birth         3194
# 2016 Birth         3194
# 2017 Birth         3194
# 2018 Birth         3194
# dtype: int64

# %%
new_df.set_index("State")
# Out:
#                Area Name 2010 Population 2011 Population 2012 Population  \
# State
# US         United States     308,745,538     311,580,009     313,874,218
# AL               Alabama       4,779,736       4,798,834       4,815,564
# AL        Autauga County          54,571          55,208          54,936
# AL        Baldwin County         182,265         186,540         190,143
# AL        Barbour County          27,457          27,350          27,174
# ...                  ...             ...             ...             ...
# WY     Sweetwater County          43,806          43,981          45,005
# WY          Teton County          21,294          21,414          21,625
# WY          Uinta County          21,118          20,893          20,994
# WY       Washakie County           8,533           8,448           8,408
# WY         Weston County           7,208           7,142           7,077
#
#       2013 Population 2014 Population 2015 Population 2016 Population  \
# State
# ...

# %%
new_df["2010 Population"]=new_df["2010 Population"].str.replace(',', '').astype(float)
new_df["2011 Population"]=new_df["2011 Population"].str.replace(',', '').astype(float)
new_df["2012 Population"]=new_df["2012 Population"].str.replace(',', '').astype(float)
new_df["2013 Population"]=new_df["2013 Population"].str.replace(',', '').astype(float)
new_df["2014 Population"]=new_df["2014 Population"].str.replace(',', '').astype(float)
new_df["2015 Population"]=new_df["2015 Population"].str.replace(',', '').astype(float)
new_df["2016 Population"]=new_df["2016 Population"].str.replace(',', '').astype(float)
new_df["2017 Population"]=new_df["2017 Population"].str.replace(',', '').astype(float)
new_df["2018 Population"]=new_df["2018 Population"].str.replace(',', '').astype(float)
new_df["2010 Birth"]=new_df["2010 Birth"].str.replace(',', '').astype(float)
new_df["2011 Birth"]=new_df["2011 Birth"].str.replace(',', '').astype(float)
new_df["2012 Birth"]=new_df["2012 Birth"].str.replace(',', '').astype(float)
new_df["2013 Birth"]=new_df["2013 Birth"].str.replace(',', '').astype(float)
new_df["2014 Birth"]=new_df["2014 Birth"].str.replace(',', '').astype(float)
new_df["2015 Birth"]=new_df["2015 Birth"].str.replace(',', '').astype(float)
new_df["2016 Birth"]=new_df["2016 Birth"].str.replace(',', '').astype(float)
new_df["2017 Birth"]=new_df["2017 Birth"].str.replace(',', '').astype(float)
new_df["2018 Birth"]=new_df["2018 Birth"].str.replace(',', '').astype(float)


new_df
# Out:
#      State          Area Name  2010 Population  2011 Population  \
# 0       US      United States      308745538.0      311580009.0
# 1       AL            Alabama        4779736.0        4798834.0
# 2       AL     Autauga County          54571.0          55208.0
# 3       AL     Baldwin County         182265.0         186540.0
# 4       AL     Barbour County          27457.0          27350.0
# ...    ...                ...              ...              ...
# 3189    WY  Sweetwater County          43806.0          43981.0
# 3190    WY       Teton County          21294.0          21414.0
# 3191    WY       Uinta County          21118.0          20893.0
# 3192    WY    Washakie County           8533.0           8448.0
# 3193    WY      Weston County           7208.0           7142.0
#
#       2012 Population  2013 Population  2014 Population  2015 Population  \
# 0         313874218.0      316057727.0      318386421.0      320742673.0
# ...

# %%
new_df.dtypes
# Out:
# State               object
# Area Name           object
# 2010 Population    float64
# 2011 Population    float64
# 2012 Population    float64
# 2013 Population    float64
# 2014 Population    float64
# 2015 Population    float64
# 2016 Population    float64
# 2017 Population    float64
# 2018 Population    float64
# 2010 Birth         float64
# 2011 Birth         float64
# 2012 Birth         float64
# 2013 Birth         float64
# 2014 Birth         float64
# 2015 Birth         float64
# 2016 Birth         float64
# 2017 Birth         float64
# 2018 Birth         float64
# dtype: object

# %%
new_df["Birth Rate 2010"]=1000*(new_df["2010 Birth"]/new_df["2010 Population"])
new_df["Birth Rate 2011"]=1000*(new_df["2011 Birth"]/new_df["2011 Population"])
new_df["Birth Rate 2012"]=1000*(new_df["2012 Birth"]/new_df["2012 Population"])
new_df["Birth Rate 2013"]=1000*(new_df["2013 Birth"]/new_df["2013 Population"])
new_df["Birth Rate 2014"]=1000*(new_df["2014 Birth"]/new_df["2014 Population"])
new_df["Birth Rate 2015"]=1000*(new_df["2015 Birth"]/new_df["2015 Population"])
new_df["Birth Rate 2016"]=1000*(new_df["2016 Birth"]/new_df["2016 Population"])
new_df["Birth Rate 2017"]=1000*(new_df["2017 Birth"]/new_df["2017 Population"])
new_df["Birth Rate 2018"]=1000*(new_df["2018 Birth"]/new_df["2018 Population"])

new_df
# Out:
#      State          Area Name  2010 Population  2011 Population  \
# 0       US      United States      308745538.0      311580009.0
# 1       AL            Alabama        4779736.0        4798834.0
# 2       AL     Autauga County          54571.0          55208.0
# 3       AL     Baldwin County         182265.0         186540.0
# 4       AL     Barbour County          27457.0          27350.0
# ...    ...                ...              ...              ...
# 3189    WY  Sweetwater County          43806.0          43981.0
# 3190    WY       Teton County          21294.0          21414.0
# 3191    WY       Uinta County          21118.0          20893.0
# 3192    WY    Washakie County           8533.0           8448.0
# 3193    WY      Weston County           7208.0           7142.0
#
#       2012 Population  2013 Population  2014 Population  2015 Population  \
# 0         313874218.0      316057727.0      318386421.0      320742673.0
# ...

# %%
new_df_AL=new_df.loc[new_df["Area Name"]=="Alabama"]
new_df_AZ=new_df.loc[new_df["Area Name"]=="Arizona"]
new_df_AK=new_df.loc[new_df["Area Name"]=="Alaska"]
new_df_AR=new_df.loc[new_df["Area Name"]=="Arkansas"]
new_df_CA=new_df.loc[new_df["Area Name"]=="California"]
new_df_CO=new_df.loc[new_df["Area Name"]=="Colorado"]
new_df_CT=new_df.loc[new_df["Area Name"]=="Connecticut"]
new_df_DE=new_df.loc[new_df["Area Name"]=="Delaware"]
new_df_FL=new_df.loc[new_df["Area Name"]=="Florida"]
new_df_GA=new_df.loc[new_df["Area Name"]=="Georgia"]
new_df_HI=new_df.loc[new_df["Area Name"]=="Hawaii"]
new_df_ID=new_df.loc[new_df["Area Name"]=="Idaho"]
new_df_IL=new_df.loc[new_df["Area Name"]=="Illinois"]
new_df_IN=new_df.loc[new_df["Area Name"]=="Indiana"]
new_df_IO=new_df.loc[new_df["Area Name"]=="Iowa"]
new_df_KS=new_df.loc[new_df["Area Name"]=="Kansas"]
new_df_KY=new_df.loc[new_df["Area Name"]=="Kentucky"]
new_df_LA=new_df.loc[new_df["Area Name"]=="Louisiana"]
new_df_ME=new_df.loc[new_df["Area Name"]=="Maine"]
new_df_MD=new_df.loc[new_df["Area Name"]=="Maryland"]
new_df_MA=new_df.loc[new_df["Area Name"]=="Massachusetts"]
new_df_MI=new_df.loc[new_df["Area Name"]=="Michigan"]
new_df_MN=new_df.loc[new_df["Area Name"]=="Minnesota"]
new_df_MS=new_df.loc[new_df["Area Name"]=="Mississippi"]
new_df_MO=new_df.loc[new_df["Area Name"]=="Missouri"]
new_df_MT=new_df.loc[new_df["Area Name"]=="Montana"]
new_df_NE=new_df.loc[new_df["Area Name"]=="Nebraska"]
new_df_NV=new_df.loc[new_df["Area Name"]=="Nevada"]
new_df_NH=new_df.loc[new_df["Area Name"]=="New Hampshire"]
new_df_NJ=new_df.loc[new_df["Area Name"]=="New Jersey"]
new_df_NM=new_df.loc[new_df["Area Name"]=="New Mexico"]
new_df_NY=new_df.loc[new_df["Area Name"]=="New York"]
new_df_NC=new_df.loc[new_df["Area Name"]=="North Carolina"]
new_df_ND=new_df.loc[new_df["Area Name"]=="North Dakota"]
new_df_OH=new_df.loc[new_df["Area Name"]=="Ohio"]
new_df_OK=new_df.loc[new_df["Area Name"]=="Oklahoma"]
new_df_OR=new_df.loc[new_df["Area Name"]=="Oregon"]
new_df_PA=new_df.loc[new_df["Area Name"]=="Pennsylvania"]
new_df_RI=new_df.loc[new_df["Area Name"]=="Rhode Island"]
new_df_SC=new_df.loc[new_df["Area Name"]=="South Carolina"]
new_df_SD=new_df.loc[new_df["Area Name"]=="South Dakota"]
new_df_TN=new_df.loc[new_df["Area Name"]=="Tennessee"]
new_df_TX=new_df.loc[new_df["Area Name"]=="Texas"]
new_df_UT=new_df.loc[new_df["Area Name"]=="Utah"]
new_df_VT=new_df.loc[new_df["Area Name"]=="Vermont"]
new_df_VA=new_df.loc[new_df["Area Name"]=="Virginia"]
new_df_WA=new_df.loc[new_df["Area Name"]=="Washington"]
new_df_WV=new_df.loc[new_df["Area Name"]=="West Virginia"]
new_df_WI=new_df.loc[new_df["Area Name"]=="Wisconsin"]
new_df_WY=new_df.loc[new_df["Area Name"]=="Wyoming"]
new_df_US=new_df.loc[new_df["Area Name"]=="United States"]



new_df_states=pd.concat([new_df_AL, new_df_AR, new_df_AK, new_df_AZ, new_df_CA, new_df_CO, new_df_CT, 
                         new_df_DE, new_df_FL, new_df_GA, new_df_HI, new_df_ID, new_df_IL, new_df_IN, 
                         new_df_IO, new_df_KS, new_df_KY, new_df_LA, new_df_ME, new_df_MD, new_df_MA, 
                         new_df_MI, new_df_MN, new_df_MS, new_df_MO, new_df_MT, new_df_NE, new_df_NV, 
                         new_df_NH, new_df_NJ, new_df_NM, new_df_NY, new_df_NC, new_df_ND, new_df_OH, 
                         new_df_OK, new_df_OR, new_df_PA, new_df_RI, new_df_SC, new_df_SD, new_df_TN, 
                         new_df_TX, new_df_UT, new_df_VT, new_df_VA, new_df_WA, new_df_WV, new_df_WI, 
                         new_df_WY, new_df_US], axis=0)


new_df_states
# Out:
#      State       Area Name  2010 Population  2011 Population  2012 Population  \
# 1       AL         Alabama        4779736.0        4798834.0        4815564.0
# 115     AR        Arkansas        2915918.0        2940407.0        2952109.0
# 69      AK          Alaska         710231.0         722038.0         730399.0
# 99      AZ         Arizona        6392017.0        6473497.0        6556629.0
# 191     CA      California       37253956.0       37641823.0       37960782.0
# 250     CO        Colorado        5029196.0        5121771.0        5193721.0
# 315     CT     Connecticut        3574097.0        3588023.0        3594395.0
# 324     DE        Delaware         897934.0         907316.0         915188.0
# 330     FL         Florida       18801310.0       19093352.0       19326230.0
# 398     GA         Georgia        9687653.0        9801578.0        9901496.0
# 558     HI          Hawaii        1360301.0        1379252.0        1394905.0
# ...

# %%
new_df_states.columns
# Out:
# Index(['State', 'Area Name', '2010 Population', '2011 Population',
#        '2012 Population', '2013 Population', '2014 Population',
#        '2015 Population', '2016 Population', '2017 Population',
#        '2018 Population', '2010 Birth', '2011 Birth', '2012 Birth',
#        '2013 Birth', '2014 Birth', '2015 Birth', '2016 Birth', '2017 Birth',
#        '2018 Birth', 'Birth Rate 2010', 'Birth Rate 2011', 'Birth Rate 2012',
#        'Birth Rate 2013', 'Birth Rate 2014', 'Birth Rate 2015',
#        'Birth Rate 2016', 'Birth Rate 2017', 'Birth Rate 2018'],
#       dtype='object')

# %%
new_df_states=new_df_states[['State', 'Area Name', 'Birth Rate 2010', 'Birth Rate 2011', 'Birth Rate 2012',
       'Birth Rate 2013', 'Birth Rate 2014', 'Birth Rate 2015',
       'Birth Rate 2016', 'Birth Rate 2017', 'Birth Rate 2018']]

new_df_states=new_df_states.rename(columns={'Area Name':'County/State', 'Birth Rate 2010':"2010", 'Birth Rate 2011':"2011", 
                                            'Birth Rate 2012':"2012",'Birth Rate 2013':"2013", 'Birth Rate 2014':"2014", 
                                            'Birth Rate 2015':"2015",'Birth Rate 2016':"2016", 'Birth Rate 2017':"2017", 
                                            'Birth Rate 2018':"2018"})
#new_df_states=new_df_states.set_index("State")
new_df_states=new_df_states.set_index("County/State")
new_df_states
# Out:
#                State      2010       2011       2012       2013       2014  \
# County/State
# Alabama           AL  2.976524  12.438230  12.266476  11.993889  12.164632
# Arkansas          AR  3.236717  13.073700  13.074043  12.832023  12.881917
# Alaska            AK  4.073323  16.206903  15.228663  15.388477  15.545146
# Arizona           AZ  3.276274  13.300848  13.052439  12.976641  12.789731
# California        CA  3.310011  13.542463  13.103813  13.051652  12.916743
# Colorado          CO  3.338307  12.870353  12.465629  12.282748  12.281690
# Connecticut       CT  2.655776  10.491014  10.252908  10.052533  10.058465
# Delaware          DE  3.171725  12.455418  12.188752  11.789251  11.775731
# Florida           FL  2.705928  11.166871  11.073500  10.887553  10.993574
# Georgia           GA  3.354476  13.529862  13.318189  12.900411  12.867116
# Hawaii            HI  3.413950  13.887237  13.546442  13.515538  13.397066
# ...

# %%
file1 = "Data/Output_data/new_unemployment.csv"
unemployment_df = pd.read_csv(file1)
unemployment_df
# Out:
#    State    County/State  Unemp Rate 2010  Unemp Rate 2011  Unemp Rate 2012  \
# 0     AL         Alabama             10.5              9.6              8.0
# 1     AZ         Arizona             10.4              9.5              8.3
# 2     AK          Alaska              7.9              7.6              7.1
# 3     AR        Arkansas              8.2              8.3              7.6
# 4     CA      California             12.2             11.7             10.4
# 5     CO        Colorado              8.7              8.4              7.9
# 6     CT     Connecticut              9.1              8.8              8.3
# 7     DE        Delaware              8.4              7.5              7.2
# 8     FL         Florida             11.1             10.0              8.5
# 9     GA         Georgia             10.5             10.2              9.2
# 10    HI          Hawaii              6.9              6.8              6.0
# ...

# %%
unemployment_df.columns
# Out:
# Index(['State', 'County/State', 'Unemp Rate 2010', 'Unemp Rate 2011',
#        'Unemp Rate 2012', 'Unemp Rate 2013', 'Unemp Rate 2014',
#        'Unemp Rate 2015', 'Unemp Rate 2016', 'Unemp Rate 2017',
#        'Unemp Rate 2018'],
#       dtype='object')

# %%
unemployment_df=unemployment_df.rename(columns={'Unemp Rate 2010':"2010", 'Unemp Rate 2011':"2011",
       'Unemp Rate 2012':"2012", 'Unemp Rate 2013':"2013", 'Unemp Rate 2014':"2014",
       'Unemp Rate 2015':"2015", 'Unemp Rate 2016':"2016", 'Unemp Rate 2017':"2017",
       'Unemp Rate 2018':"2018"})
unemployment_df=unemployment_df.set_index("County/State")
unemployment_df
# Out:
#                State  2010  2011  2012  2013  2014  2015  2016  2017  2018
# County/State
# Alabama           AL  10.5   9.6   8.0   7.2   6.8   6.1   5.8   4.4   3.9
# Arizona           AZ  10.4   9.5   8.3   7.7   6.8   6.1   5.4   4.9   4.8
# Alaska            AK   7.9   7.6   7.1   7.0   6.9   6.5   6.9   7.0   6.6
# Arkansas          AR   8.2   8.3   7.6   7.2   6.0   5.0   4.0   3.7   3.7
# California        CA  12.2  11.7  10.4   8.9   7.5   6.2   5.5   4.8   4.2
# Colorado          CO   8.7   8.4   7.9   6.9   5.0   3.9   3.2   2.7   3.3
# Connecticut       CT   9.1   8.8   8.3   7.8   6.6   5.7   5.1   4.7   4.1
# Delaware          DE   8.4   7.5   7.2   6.7   5.7   4.9   4.5   4.5   3.8
# Florida           FL  11.1  10.0   8.5   7.2   6.3   5.5   4.8   4.2   3.6
# Georgia           GA  10.5  10.2   9.2   8.2   7.1   6.0   5.4   4.7   3.9
# Hawaii            HI   6.9   6.8   6.0   4.9   4.4   3.6   3.0   2.4   2.4
# ...

# %%
unemployment_df.columns
# Out:
# Index(['State', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018'],
#       dtype='object')

# %%
total_df=pd.merge(unemployment_df,new_df_states , on="County/State")
total_df=total_df.set_index("County/State")
total_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-136-8bb50e091d56> in <module>
#       1 total_df=pd.merge(unemployment_df,new_df_states , on="County/State")
# ----> 2 total_df=total_df.set_index("County/State")
#       3 total_df
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4409
#    4410         if missing:
# -> 4411             raise KeyError("None of {} are in the columns".format(missing))
#    4412
#    4413         if inplace:
#
# KeyError: "None of ['County/State'] are in the columns"

# %%
def unemp_states(source):
    return source[['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017','2018']]

def birth_states(source):
    return source[['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017','2018']]

# %%
#Region I: Connecticut, Maine, Massachusetts, New Hampshire, Rhode Island, Vermont
#Region 1:CT, ME, MA, NH, RI, VT

Region1_birth=new_df_states.loc[(new_df_states["State"]=="US")|(new_df_states["State"]=="CT")|(new_df_states["State"]=="ME")|
                                (new_df_states["State"]=="MA")|(new_df_states["State"]=="NH")|(new_df_states["State"]=="RI")|
                                (new_df_states["State"]=="VT")]
                               

Region1_unemp=unemployment_df.loc[(unemployment_df["State"]=="US")|(unemployment_df["State"]=="CT")|(unemployment_df["State"]=="ME")|
                                  (unemployment_df["State"]=="MA")|(unemployment_df["State"]=="NH")|(unemployment_df["State"]=="RI")|
                                  (unemployment_df["State"]=="VT")]

Region1_unemp_rate = unemp_states(Region1_unemp)
Region1_birth_rate = birth_states(Region1_birth)

# %%
Region1_birth_rate.T.plot.line(figsize=(15,5),marker='o')
plt.grid()
plt.title("Region 1: Birth Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Birth Rate (%)")
plt.savefig("Data/Output_data/BR_Region1")

Region1_unemp_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 1: Unemployment Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Unemployment Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/UR_Region1")
plt.show()

# %%
#Region II: New Jersey, New York, Puerto Rico, US Virgin Islands
#Region2:NJ, NY
Region2_birth=new_df_states.loc[(new_df_states["State"]=="NJ")|(new_df_states["State"]=="US")|(new_df_states["State"]=="NY")]

Region2_unemp=unemployment_df.loc[(unemployment_df["State"]=="NJ")|(unemployment_df["State"]=="NY")]

Region2_unemp_rate = unemp_states(Region2_unemp)
Region2_birth_rate = birth_states(Region2_birth)

# %%
Region2_birth_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 2: Birth Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Birth Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/BR_Region2")

Region2_unemp_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 2: Unemployment Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Unemployment Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/UR_Region2")

plt.show()

# %%
#Region III: Delaware, District of Columbia, Maryland, Pennsylvania, Virginia, West Virginia
#Region III:DE, MD, PA, VA, WV 
Region3_birth=new_df_states.loc[(new_df_states["State"]=="US")|(new_df_states["State"]=="DE")|(new_df_states["State"]=="MD")|
                               (new_df_states["State"]=="PA")|(new_df_states["State"]=="VA")|
                               (new_df_states["State"]=="WV")]

Region3_unemp=unemployment_df.loc[(unemployment_df["State"]=="DE")|(unemployment_df["State"]=="MD")|
                                 (unemployment_df["State"]=="PA")|(unemployment_df["State"]=="VA")|
                                 (unemployment_df["State"]=="WV")]

Region3_unemp_rate = unemp_states(Region3_unemp)
Region3_birth_rate = birth_states(Region3_birth)

# %%
Region3_birth_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 3: Birth Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Birth Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/BR_Region3")

Region3_unemp_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 3: Unemployment Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Unemployment Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/UR_Region3")
plt.show()

# %%
# Region 4:Alabama, Florida, Georgia, Kentucky, Mississippi, North Carolina, South Carolina, Tennessee
#Region 4:AL, FL, GA, KT, MS, NC, SC, TN 
Region4_birth=new_df_states.loc[(new_df_states["State"]=="AL")|(new_df_states["State"]=="US")|(new_df_states["State"]=="FL")|
                               (new_df_states["State"]=="GA")|(new_df_states["State"]=="KY")|
                               (new_df_states["State"]=="MS")|(new_df_states["State"]=="NC")|
                               (new_df_states["State"]=="SC")|(new_df_states["State"]=="TN")]

Region4_unemp=unemployment_df.loc[(unemployment_df["State"]=="AL")|(unemployment_df["State"]=="FL")|
                                 (unemployment_df["State"]=="GA")|(unemployment_df["State"]=="KY")|
                                 (unemployment_df["State"]=="MS")|(unemployment_df["State"]=="NC")|
                                 (unemployment_df["State"]=="SC")|(unemployment_df["State"]=="TN")]

Region4_unemp_rate = unemp_states(Region4_unemp)
Region4_birth_rate = birth_states(Region4_birth)

# %%
Region4_birth_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 4: Birth Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Birth Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/BR_Region4")

Region4_unemp_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 4: Unemployment Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Unemployment Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/UR_Region4")

plt.show()

# %%
# Region V: Illinois, Indiana, Michigan, Minnesota, Ohio, Wisconsin
#Region 5:IL, IN, MI, MN, OH, WI
Region5_birth=new_df_states.loc[(new_df_states["State"]=="IL")|(new_df_states["State"]=="US")|(new_df_states["State"]=="IN")|
                               (new_df_states["State"]=="MI")|(new_df_states["State"]=="MN")|
                               (new_df_states["State"]=="OH")|(new_df_states["State"]=="WI")]

Region5_unemp=unemployment_df.loc[(unemployment_df["State"]=="IL")|(unemployment_df["State"]=="IN")|
                                 (unemployment_df["State"]=="MI")|(unemployment_df["State"]=="MN")|
                                 (unemployment_df["State"]=="OH")|(unemployment_df["State"]=="WI")]

Region5_unemp_rate = unemp_states(Region5_unemp)
Region5_birth_rate = birth_states(Region5_birth)

# %%
Region5_birth_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 5: Birth Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Birth Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/BR_Region5")

Region5_unemp_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 5: Unemployment Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Unemployment Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/UR_Region5")

plt.show()

# %%
#Region VI: Arkansas, Louisiana, New Mexico, Oklahoma, Texas
#Region 6: AR, LA, NM,  OK, TX
Region6_birth=new_df_states.loc[(new_df_states["State"]=="AR")|(new_df_states["State"]=="US")|(new_df_states["State"]=="LA")|
                               (new_df_states["State"]=="NM")|(new_df_states["State"]=="OK")|
                               (new_df_states["State"]=="TX")]

Region6_unemp=unemployment_df.loc[(unemployment_df["State"]=="AR")|(unemployment_df["State"]=="LA")|
                                 (unemployment_df["State"]=="NM")|(unemployment_df["State"]=="OK")|
                                 (unemployment_df["State"]=="TX")]

Region6_unemp_rate = unemp_states(Region6_unemp)
Region6_birth_rate = birth_states(Region6_birth)

# %%
Region6_birth_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 6: Birth Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Birth Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/BR_Region6")

Region6_unemp_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 6: Unemployment Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Unemployment Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/UR_Region6")

plt.show()

# %%
#Region VII: Iowa, Kansas, Missouri, Nebraska
#Region 7: IA, KS, MO,  NE
Region7_birth=new_df_states.loc[(new_df_states["State"]=="IA")|(new_df_states["State"]=="US")|(new_df_states["State"]=="KS")|
                               (new_df_states["State"]=="MO")|(new_df_states["State"]=="NE")]

Region7_unemp=unemployment_df.loc[(unemployment_df["State"]=="IA")|(unemployment_df["State"]=="KS")|
                                 (unemployment_df["State"]=="MO")|(unemployment_df["State"]=="NE")]

Region7_unemp_rate = unemp_states(Region7_unemp)
Region7_birth_rate = birth_states(Region7_birth)

# %%
Region7_birth_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 7: Birth Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Birth Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/BR_Region7")

Region7_unemp_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 7: Unemployment Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Unemployment Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/UR_Region7")

plt.show()

# %%
#Region VIII: Colorado, Montana, North Dakota, South Dakota, Utah, Wyoming
#Region 8: CO, MT, ND,  SD, UT, WY
Region8_birth=new_df_states.loc[(new_df_states["State"]=="CO")|(new_df_states["State"]=="US")|(new_df_states["State"]=="MT")|
                               (new_df_states["State"]=="ND")|(new_df_states["State"]=="SD")|
                               (new_df_states["State"]=="UT")|(new_df_states["State"]=="WY")]

Region8_unemp=unemployment_df.loc[(unemployment_df["State"]=="")|(unemployment_df["State"]=="MT")|
                                 (unemployment_df["State"]=="ND")|(unemployment_df["State"]=="SD")|
                                 (unemployment_df["State"]=="UT")|(unemployment_df["State"]=="WY")]

Region8_unemp_rate = unemp_states(Region8_unemp)
Region8_birth_rate = birth_states(Region8_birth)

# %%
Region8_birth_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 8: Birth Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Birth Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/BR_Region8")

Region8_unemp_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 8: Unemployment Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Unemployment Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/UR_Region8")

plt.show()

# %%
#Region IX: Arizona, California, Hawaii, Nevada, American Samoa, Guam, Northern Mariana Islands
#Region 8: AZ, CA, HI,  NV
Region9_birth=new_df_states.loc[(new_df_states["State"]=="AZ")|(new_df_states["State"]=="US")|(new_df_states["State"]=="CA")|
                               (new_df_states["State"]=="HI")|(new_df_states["State"]=="NV")]

Region9_unemp=unemployment_df.loc[(unemployment_df["State"]=="AZ")|(unemployment_df["State"]=="CA")|
                                 (unemployment_df["State"]=="HI")|(unemployment_df["State"]=="NV")]

Region9_unemp_rate = unemp_states(Region9_unemp)
Region9_birth_rate = birth_states(Region9_birth)

# %%
Region9_birth_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 9: Birth Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Birth Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/BR_Region9")

Region9_unemp_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 9: Unemployment Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Unemployment Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/UR_Region9")

plt.show()

# %%
#Region X: Alaska, Idaho, Oregon, Washington
#Region 10: AK, ID, OR,  WA
Region10_birth=new_df_states.loc[(new_df_states["State"]=="AK")|(new_df_states["State"]=="US")|(new_df_states["State"]=="ID")|
                               (new_df_states["State"]=="OR")|(new_df_states["State"]=="WA")]

Region10_unemp=unemployment_df.loc[(unemployment_df["State"]=="AK")|(unemployment_df["State"]=="ID")|
                                 (unemployment_df["State"]=="OR")|(unemployment_df["State"]=="WA")]

Region10_unemp_rate = unemp_states(Region10_unemp)
Region10_birth_rate = birth_states(Region10_birth)

# %%
Region10_birth_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 10: Birth Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Birth Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/BR_Region10")

Region10_unemp_rate.T.plot.line(figsize=(15,5),marker='o')
plt.title("Region 10: Unemployment Rate from 2010-2018", fontsize=14)
plt.xlabel("Years")
plt.ylabel("Unemployment Rate (%)")
plt.grid()
plt.savefig("Data/Output_data/UR_Region10")

plt.show()
